# %% [markdown]
# ## RCS Python Errors and Exceptions

# %%
# There are (at least) two distinguishable kinds of errors: syntax errors and exceptions.

# %%
## Syntax errors affect everyone , WE all do it!

# %%
if True:
    print("hullo")
# Out:
# hullo

# %%
eh?

# %%
print("hi")
# Out:
#   File "<ipython-input-3-3cda29d2e5c3>", line 1
#     print("hi)
#               ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# ## Exceptions
#
# Errors detected during execution are called **exceptions** and are not unconditionally fatal:

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-9e1622b385b6> in <module>()
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
monty*3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-04dc0350fe8f> in <module>()
# ----> 1 monty*3
#
# NameError: name 'monty' is not defined

# %%
"5"+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-d04f8017a6f6> in <module>()
# ----> 1 "5"+5
#
# TypeError: must be str, not int

# %% [markdown]
# ## Handling Exceptions

# %%
## Bad idea to catch ALL exceptions!

try:
    1/0
except:
    print("Exception Raised")
# Out:
# Exception Raised

# %%
try:
    1/0
    #something()
except OSError as err:
    print(f'OS Error {err}')
except NameError as err:
    print(f'Name Error: ({err})')
except Exception as err:
    print(f'Unknowne exception ({err})')
# Out:
# Unknowne exception (division by zero)

# %%
#Better to cach specific ones
try:
    1/0
except ArithmeticError:
    print("Arithmetic Error, you diving by 0 again?")
# Out:
# Arithmetic Error, you diving by 0 again?

# %% [markdown]
# ## Optional else
#
# The try … except statement has an optional else clause, which, when present, must follow all except clauses. It is useful for code that must be executed if the try clause does not raise an exception.

# %%
import sys
for arg in sys.argv[1:]:
    try:
        f = open(arg, 'r')
    except OSError:
        print('cannot open', arg)
    else:
        print(arg, 'has', len(f.readlines()), 'lines')
        f.close()
# Out:
# cannot open -f
# C:\Users\vsd\AppData\Roaming\jupyter\runtime\kernel-40aa0d35-57c5-4e35-bb44-1b7fed0dadf3.json has 12 lines

# %%
## You can raise a new exception yourself!
# The raise statement allows the programmer to force a specified exception to occur. For example:

# %%
raise NameError('OhSup!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-fac693ac3125> in <module>()
# ----> 1 raise NameError('OhSup!')
#
# NameError: OhSup!

# %%
# If you need to determine whether an exception was raised but don’t intend to handle it, a simpler form of the raise statement allows you to re-raise the exception:

# %%
try:
    raise NameError('HiThere')
except NameError:
    print('An exception flew by!')
    raise
# Out:
# An exception flew by!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-bf6ef4926f8c> in <module>()
#       1 try:
# ----> 2     raise NameError('HiThere')
#       3 except NameError:
#       4     print('An exception flew by!')
#       5     raise
#
# NameError: HiThere

# %%
## A finally clause is always executed before leaving the try statement, whether an excbeption has occurred or not.

# %%
try:
    raise NameError
finally:
    print('Finally did it')
# Out:
# Finally did it
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-54f317e727ec> in <module>()
#       1 try:
# ----> 2     raise NameError
#       3 finally:
#       4     print('Finally did it')
#
# NameError:

# %% [markdown]
# ### List of Concrete Exceptions
# * https://docs.python.org/3.6/library/exceptions.html
